# %% [markdown]
# ## LLM Knowledge Extraction
#
# ### **Main Objective**
# To leverage Generative AI (Google Gemini) to "read" the unstructured legal opinions and extract structured entities: **Offense**, **Punishment**, and **Appellate Decision**.
#
# ### **Technical Logic**
# This script acts as the "intelligence layer" of the pipeline, converting raw text into queryable data:
#
# * **Batch Processing & Context Management:** It processes cases in groups (batches of 10) to maximize API throughput and reduce latency. Crucially, it implements **text truncation** (`head_matter` to 4000 chars, `opinions` to 12000 chars) to ensure the input fits within the LLM's context window (token limit) while preserving the most critical initial sections of the judgment.
# * **Fault Tolerance & Rate Limiting:** It features a robust network layer with a **retry mechanism** using exponential backoff. This automatically handles API quotas (HTTP 429 Rate Limits) and temporary server instability (HTTP 503) without crashing the pipeline. It also includes "resume capability," skipping IDs that have already been processed.
# * **Hybrid Output Parsing:** Recognizing that LLMs can be unpredictable (sometimes adding conversational text around the requested JSON), the script uses a **dual-parsing strategy**: it first attempts standard JSON decoding, and if that fails, it falls back to **Regular Expressions (Regex)** to surgically extract valid JSON arrays or objects from the raw text response.

# %%
import pandas as pd
import json
import requests
from pprint import pprint
import os
import time
import random
import re

# --- JSON extraction helpers ---
def extract_json_array(text):
    """Try to extract a full JSON array from text using regex."""
    match = re.search(r'\[.*\]', text, re.DOTALL)
    if match:
        try:
            return json.loads(match.group(0))
        except json.JSONDecodeError:
            return None
    return None

def extract_json_objects(text):
    """Extract individual JSON objects from text using regex."""
    matches = re.findall(r'\{.*?\}', text, re.DOTALL)
    objs = []
    for m in matches:
        try:
            objs.append(json.loads(m))
        except json.JSONDecodeError:
            continue
    return objs

# --- Load API key ---
api_key = os.getenv("GEMINI_API_KEY") or os.getenv("GOOGLE_API_KEY")

if not api_key:
    key_file = "key.txt"
    try:
        with open(key_file, "r", encoding="utf-8") as f:
            api_key = f.read().strip()
            print(f" API Key loaded successfully from {key_file}.")
    except FileNotFoundError:
        print(f" ERROR: API Key not found. Please set GEMINI_API_KEY or create '{key_file}'.")
        api_key = ""
else:
    print(" API Key loaded successfully from environment variables.")

# --- Gemini API Config ---
GEMINI_MODEL = "gemini-2.5-flash-preview-09-2025" 
API_URL = f"https://generativelanguage.googleapis.com/v1beta/models/{GEMINI_MODEL}:generateContent?key={api_key}"

HEADERS = {
    'Content-Type': 'application/json',
}

# --- Configuration (TEXAS) ---
csv_file = "Test/case_law_csv/case_texts.csv" 
output_file = "case_details_tx_with_llm.json"
prompt_template_file = "prompt_example.txt"

batch_size = 1
save_interval = 5 

# --- Load CSV ---
print(f"Loading cases from {csv_file}...")
if not os.path.exists(csv_file):
    print(f"ERROR: File {csv_file} not found. Did you run json_to_csv_parser_tx.py?")
    exit()

df = pd.read_csv(csv_file)

# --- Load prompt template ---
if not os.path.exists(prompt_template_file):
    print(f"ERROR: {prompt_template_file} not found.")
    exit()

with open(prompt_template_file, "r", encoding="utf-8") as f:
    prompt_template = f.read()

# --- Load existing results (Resume logic) ---
if os.path.exists(output_file):
    try:
        with open(output_file, "r", encoding="utf-8") as f:
            results = json.load(f)
        print(f" Loaded {len(results)} existing results from {output_file}")
    except json.JSONDecodeError:
        print(f" Could not load existing JSON from {output_file}. Starting fresh.")
        results = []
else:
    results = []

# ============================================================
# MODIFICA PER RIPARAZIONE: Rimuoviamo i casi falliti (Skipped)
# ============================================================
initial_count = len(results)
# Teniamo solo i risultati che hanno dati validi O che hanno un raw_output (quindi non sono stati skippati)
results = [r for r in results if r.get("offense") is not None or r.get("raw_output") is not None]
removed_count = initial_count - len(results)

if removed_count > 0:
    print(f"     REPAIR MODE: Removed {removed_count} failed cases (None/Skipped) from memory.")
    print(f"     They will be re-processed in this run.")
# ============================================================

processed_ids = {int(r.get("id")) for r in results if r.get("id") is not None}

# --- Prepare rows to process ---
if 'id' not in df.columns:
    raise ValueError("CSV file must contain an 'id' column.")

# Convert ID column to numeric for comparison
df['id_numeric'] = pd.to_numeric(df['id'], errors='coerce').fillna(-1).astype(int)

# Filtra le righe già processate
rows_to_process = [row for _, row in df.iterrows() if row["id_numeric"] not in processed_ids and row["id_numeric"] != -1]

# CALCOLO TOTAL BATCHES
total_batches = (len(rows_to_process) + batch_size - 1) // batch_size

print(f"Found {len(rows_to_process)} cases to process in {total_batches} batches.")

# --- Loop over batches ---
for batch_idx in range(total_batches):
    batch_rows = rows_to_process[batch_idx * batch_size : (batch_idx + 1) * batch_size]
    print(f"\n=== Processing batch {batch_idx + 1}/{total_batches} ({len(batch_rows)} cases) ===")

    # Build a single prompt for the batch
    batch_prompts = []
    for row in batch_rows:
        # OTTIMIZZAZIONE: Troncamento del testo
        raw_head = str(row["head_matter"]) if pd.notna(row["head_matter"]) else ""
        raw_opinions = str(row["opinions"]) if pd.notna(row["opinions"]) else ""

        head_matter_full = raw_head[:4000] 
        opinions_full = raw_opinions[:12000]

        case_prompt = prompt_template.format(
            id=row["id"],
            head_matter=head_matter_full,
            opinions=opinions_full
        )
        batch_prompts.append(case_prompt)

    system_instruction = (
        "You are a legal assistant. Extract offense, punishment, and decision from court cases. "
        "Your output MUST be ONLY a valid JSON array of objects with keys: id, offense, punishment, decision. "
        "No commentary, no extra text."
    )

    user_query = "Process the following cases and return the structured JSON:\n\n" + "\n\n".join(batch_prompts)
    
    # Debug della lunghezza del prompt
    query_length = len(user_query)
    print(f"DEBUG: Total prompt length for this batch: {query_length} characters.")

    # Construct the Gemini payload
    # ... dentro il ciclo for ...

    # Construct the Gemini payload CON SAFETY SETTINGS
    payload = {
        "contents": [{"parts": [{"text": user_query}]}],
        "systemInstruction": {"parts": [{"text": system_instruction}]},
        "safetySettings": [
            {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_CIVIC_INTEGRITY", "threshold": "BLOCK_NONE"}
        ],
        "generationConfig": {
            "maxOutputTokens": 2048,
            "responseMimeType": "application/json"
        }
    
    }

    # --- Retry LLM call ---
    max_retries = 5
    output_text = None
    for attempt in range(1, max_retries + 1):
        try:
            response = requests.post(API_URL, headers=HEADERS, json=payload)
            
            if response.status_code == 429:
                # Se colpito il limite, fai una pausa LUNGA per resettare
                wait_time = 30 + (10 * attempt)
                print(f" Rate Limit (429). Pausing for {wait_time}s...", end="\r")
                time.sleep(wait_time)
                continue
            
            if response.status_code == 503:
                time.sleep(5 * attempt)
                continue

            response.raise_for_status()
            
            result = response.json()
            candidate = result.get('candidates', [{}])[0]
            parts = candidate.get('content', {}).get('parts', [{}])
            output_text = parts[0].get('text', '').strip()

            if not output_text:
                # DEBUG: Stampiamo perché è vuoto (es. SAFETY)
                print(f" DEBUG FAILURE - Full Response: {result}")
                finish_reason = candidate.get('finishReason')
                if finish_reason == "SAFETY":
                    print(" BLOCKED BY SAFETY FILTERS (Fix applied?)")
                
                raise ValueError(f"Empty text. Finish Reason: {finish_reason}")

            print(f" Attempt {attempt} successful.")
            break
            
        except Exception as e:
            print(f" Attempt {attempt} failed: {e}")
            output_text = None
            if attempt < max_retries:
                time.sleep(2 ** attempt + random.uniform(0, 1))

    # --- Parse JSON safely ---
    if not output_text:
        print(" Skipping batch (No output).")
        batch_results = [{"id": int(row["id_numeric"]), "offense": None, "punishment": None, "decision": None, "raw_output": None} for row in batch_rows]
    else:
        try:
            batch_results = json.loads(output_text)
            if isinstance(batch_results, dict): batch_results = [batch_results]
        except json.JSONDecodeError:
            batch_results = extract_json_array(output_text) or extract_json_objects(output_text)
            
            if not batch_results:
                print(" No valid JSON found, storing raw output.")
                batch_results = [{"id": int(row["id_numeric"]), "offense": None, "punishment": None, "decision": None, "raw_output": output_text} for row in batch_rows]

    # Normalize IDs
    normalized_results = []
    # Create a map of ID -> Row for quick lookup
    batch_map = {int(r["id_numeric"]): r for r in batch_rows}
    
    # Process returned results
    if batch_results:
        for res in batch_results:
            res_id = res.get("id")
            if res_id is not None:
                try:
                    res_id = int(res_id)
                    if res_id in batch_map:
                        normalized_results.append(res)
                        del batch_map[res_id] # Mark as found
                except ValueError:
                    pass
    
    # Add missing cases as nulls
    for missing_id in batch_map:
        normalized_results.append({"id": missing_id, "offense": None, "punishment": None, "decision": None, "error": "LLM skipped this case"})

    # Pretty print snippet
    pprint(normalized_results[:2])
    
    # Store results
    results.extend(normalized_results)

    # --- Save intermediate results ---
    if (batch_idx + 1) % save_interval == 0 or batch_idx == total_batches - 1:
        with open(output_file, "w", encoding="utf-8") as f:
            json.dump(results, f, indent=2, ensure_ascii=False)
        print(f" Saved intermediate results ({len(results)} total)")
    
    # Pausa dinamica per evitare blocchi
    print(" Cooling down API for 5 seconds...")
    time.sleep(5) 

print(f"\n LLM outputs saved to {output_file}")
# Out:
#  API Key loaded successfully from key.txt.
# Loading cases from Test/case_law_csv/case_texts.csv...
#  Loaded 7732 existing results from case_details_tx_with_llm.json
#      REPAIR MODE: Removed 25 failed cases (None/Skipped) from memory.
#      They will be re-processed in this run.
# Found 20143 cases to process in 20143 batches.
#
# === Processing batch 1/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10963 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed, and remanded',
#   'id': '5149801',
#   'offense': 'Burglary (in the daytime) concerning failure to define '
#              "'breaking'",
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 2/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11612 characters.
#  Attempt 2 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5149615,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 3/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12019 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5154672',
#   'offense': 'Sale of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one and one-half years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 4/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8395 characters.
#  Attempt 1 successful.
# [{'decision': 'Dismissed',
#   'id': '5154922',
#   'offense': 'Forfeiture of Appearance Bond',
#   'punishment': 'None stated'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 5/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7272 characters.
#  Attempt 1 successful.
# [{'decision': 'Appeal dismissed',
#   'id': '5154290',
#   'offense': 'Forfeiture of Appearance Bond',
#   'punishment': 'None stated'}]
#  Saved intermediate results (7712 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 6/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12520 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5154481',
#   'offense': 'Burglary',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 7/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8803 characters.
#  Attempt 2 successful.
# [{'decision': 'Bail reduced',
#   'id': '5153340',
#   'offense': 'Habeas Corpus / Appeal of Bail Denial for Capital Offense '
#              '(Homicide)',
#   'punishment': 'Bail set at $2,500'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 8/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 6829 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and bail granted',
#   'id': '5154342',
#   'offense': 'Appeal concerning denial of bail for murder',
#   'punishment': '$2,500 bail granted'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 9/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12265 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5157346,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 10/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8653 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5156615',
#   'offense': 'Theft of cattle',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Saved intermediate results (7717 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 11/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7791 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5153622',
#   'offense': 'Rape upon a female under eighteen years of age',
#   'punishment': 'Five years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 12/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18396 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5154669',
#   'offense': 'Murder',
#   'punishment': 'Death'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 13/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8618 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5156217',
#   'offense': 'Manufacturing intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 14/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11364 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5154044',
#   'offense': 'Murder',
#   'punishment': 'Ninety-nine years confinement in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 15/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8857 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5156252,
#   'offense': None,
#   'punishment': None}]
#  Saved intermediate results (7722 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 16/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9335 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5154615',
#   'offense': 'Unlawful transportation of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 17/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7541 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5155794',
#   'offense': 'Burglary; appeal contesting revocation of suspended sentence and '
#              'cumulation of sentences',
#   'punishment': 'Five years in the penitentiary, cumulated with a subsequent '
#                 'two-year sentence'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 18/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11815 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5156680',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 19/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9492 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5154944',
#   'offense': 'Maintaining a house, building and room as a common nuisance '
#              '(unlawfully keeping and possessing intoxicating liquors for the '
#              'purpose of sale)',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 20/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18421 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5153166',
#   'offense': 'Murder / Habeas Corpus challenging revocation of conditional '
#              'pardon',
#   'punishment': 'Ninety-nine years imprisonment in the State Penitentiary '
#                 '(reinstated)'}]
#  Saved intermediate results (7727 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 21/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 15429 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5155265',
#   'offense': 'Theft of an automobile over the value of $50',
#   'punishment': 'Five years’ confinement in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 22/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11561 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5154781',
#   'offense': 'Rape',
#   'punishment': 'Twenty-five years confinement in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 23/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9568 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5157315',
#   'offense': 'Theft',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 24/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10471 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5153821',
#   'offense': 'Assault to murder',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 25/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11627 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5155583',
#   'offense': 'Unlawful possession of equipment for manufacturing intoxicating '
#              'liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Saved intermediate results (7732 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 26/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10479 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5154387,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 27/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13116 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5156138',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year and six months'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 28/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 16877 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motions for rehearing overruled and refused)',
#   'id': '5153445',
#   'offense': 'Robbery with firearms',
#   'punishment': 'Webb: five years; Menick: ten years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 29/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11979 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5156650',
#   'offense': 'Manufacturing intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 30/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18501 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5154887',
#   'offense': 'Robbery with firearms',
#   'punishment': 'Death'}]
#  Saved intermediate results (7737 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 31/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14220 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motions for rehearing overruled/denied)',
#   'id': '5153241',
#   'offense': 'Possession of intoxicating liquor for purposes of sale',
#   'punishment': 'Confinement in the penitentiary for a period of one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 32/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18347 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5155991',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for a period of five years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 33/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12321 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5157393',
#   'offense': 'Assault with intent to murder',
#   'punishment': 'Confinement in the penitentiary for 2 years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 34/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10523 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158720',
#   'offense': 'Unlawful possession of equipment for the manufacture of '
#              'intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 35/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10262 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Rehearing Overruled',
#   'id': '5157091',
#   'offense': 'Transportation of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of two years'}]
#  Saved intermediate results (7742 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 36/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13889 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5156871',
#   'offense': 'Wilfully refusing to support his minor children',
#   'punishment': 'A fine of twenty-five dollars'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 37/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9499 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5157037',
#   'offense': 'Unlawful manufacture of intoxicating liquor',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 38/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9272 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5154728',
#   'offense': 'Forgery',
#   'punishment': 'Confinement in the penitentiary for a period of five years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 39/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12482 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5156085',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 40/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8138 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5156114',
#   'offense': 'Fraudulently receiving a stolen automobile (second count of '
#              'indictment)',
#   'punishment': 'Five years in the penitentiary'}]
#  Saved intermediate results (7747 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 41/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10420 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5155424',
#   'offense': 'Theft of cattle',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 42/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 17073 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5155178',
#   'offense': 'Embezzlement',
#   'punishment': 'Confinement in the penitentiary for five years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 43/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11380 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5154863',
#   'offense': 'Possessing intoxicating liquor for purposes of sale',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 44/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12114 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Motion for rehearing overruled',
#   'id': '5156982',
#   'offense': 'Unlawful transportation of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 45/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7922 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5153907',
#   'offense': 'Assault with intent to murder',
#   'punishment': 'H. B. Crowder and Sid Crowder: five years confinement in the '
#                 'penitentiary; Walter Stein: two years confinement in the '
#                 'penitentiary'}]
#  Saved intermediate results (7752 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 46/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9105 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5156379',
#   'offense': 'Aggravated assault',
#   'punishment': 'One year in the county jail'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 47/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9798 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5155290,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 48/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7035 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5157874,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 49/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18444 characters.
#  Attempt 1 successful.
# [{'decision': 'Relators discharged',
#   'id': '5157915',
#   'offense': 'Contempt of court for arresting an individual on bail pending a '
#              'habeas corpus hearing',
#   'punishment': 'Committed to jail for a period of 24 hours'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 50/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18297 characters.
#  Attempt 1 successful.
# [{'decision': 'Writ denied (Applicant remanded)',
#   'id': '5157144',
#   'offense': 'Contempt of court (persistent disregard of rulings by counsel '
#              'during trial)',
#   'punishment': 'Fine of ten dollars and commitment to the sheriff until paid'}]
#  Saved intermediate results (7757 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 51/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8352 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and dismissed',
#   'id': '5158289',
#   'offense': 'Aggravated assault',
#   'punishment': 'A fine of one hundred dollars'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 52/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9798 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5157551,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 53/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8247 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158356',
#   'offense': 'Unlawful transportation of intoxicating liquors',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 54/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8018 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and dismissed',
#   'id': '5157675',
#   'offense': 'Burglary (Indictment fatally defective)',
#   'punishment': 'Five years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 55/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7011 characters.
#  Attempt 1 successful.
# [{'decision': 'Dismissed',
#   'id': '5158419',
#   'offense': 'Manufacturing intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Saved intermediate results (7762 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 56/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7052 characters.
#  Attempt 1 successful.
# [{'decision': 'Reformed and affirmed',
#   'id': '5157779',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'Not less than one year nor more than fourteen months in the '
#                 'penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 57/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8984 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and bail granted',
#   'id': '5157851',
#   'offense': 'Murder / Appeal from order refusing bail',
#   'punishment': 'Bail allowed in the sum of $5,000.00 each'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 58/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7314 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158150',
#   'offense': 'Murder',
#   'punishment': 'Confinement in the penitentiary for not less than two nor '
#                 'more than 99 years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 59/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 6896 characters.
#  Attempt 1 successful.
# [{'decision': 'Dismissed',
#   'id': '5158521',
#   'offense': 'Unlawfully carrying a pistol',
#   'punishment': '$100.00 fine'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 60/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7818 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and bail granted',
#   'id': '5157957',
#   'offense': 'Murder (Habeas Corpus Petition for Bail)',
#   'punishment': 'Bail granted in the sum of $10,000.00'}]
#  Saved intermediate results (7767 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 61/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18303 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158583',
#   'offense': 'Murder',
#   'punishment': '15 years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 62/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14362 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158177',
#   'offense': 'Unlawful manufacture of spiritous intoxicating liquor',
#   'punishment': 'Three years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 63/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13555 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158886',
#   'offense': 'Knowingly becoming indebted to a state bank by an officer '
#              'without first having obtained the written consent of the '
#              'majority of the board of directors',
#   'punishment': 'Confinement in the penitentiary for ten years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 64/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8452 characters.
#  Attempt 1 successful.
# [{'decision': 'Reformed',
#   'id': '5157977',
#   'offense': 'Passing a forged instrument (motion to correct judgment/sentence '
#              'structure)',
#   'punishment': 'Confinement in the penitentiary for a period of not less than '
#                 'two nor more than five years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 65/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18327 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158316',
#   'offense': 'Murder of Clarence Smith',
#   'punishment': 'Nine years’ confinement in the penitentiary'}]
#  Saved intermediate results (7772 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 66/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8669 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158008',
#   'offense': 'Keeping a disorderly house',
#   'punishment': 'Twenty days in jail and a fine of $200.00'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 67/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9193 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed as to Emil Enderli; Reversed as to Louis Enderli',
#   'id': '5158391',
#   'offense': 'Habeas Corpus appeal regarding denial of bail for the murder of '
#              'William Whitehead',
#   'punishment': 'Custody without bail affirmed (Emil Enderli); Bail granted in '
#                 'the sum of $2500.00 (Louis Enderli)'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 68/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12176 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5158080',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'One year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 69/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9424 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158456',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 70/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11693 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158117',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Saved intermediate results (7777 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 71/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10265 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158486',
#   'offense': 'Murder',
#   'punishment': 'Death'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 72/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12107 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158219',
#   'offense': 'Unlawfully possessing for the purpose of sale intoxicating '
#              'liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 73/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9729 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158557',
#   'offense': 'Manufacture of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 74/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9015 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158256',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 75/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9061 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158038',
#   'offense': 'Unlawful possession for the purpose of sale of intoxicating '
#              'liquor',
#   'punishment': 'One year'}]
#  Saved intermediate results (7782 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 76/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13035 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5159155',
#   'offense': 'Transportation of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 77/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14154 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5157941',
#   'offense': 'Rape',
#   'punishment': 'Five years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 78/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 16387 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed / Motion for rehearing overruled',
#   'id': '5160123',
#   'offense': 'Burglary',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 79/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11289 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5162616',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 80/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14416 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5159733',
#   'offense': 'Unlawful possession for the purpose of sale of intoxicating '
#              'liquor',
#   'punishment': 'Two years'}]
#  Saved intermediate results (7787 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 81/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18481 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5161890',
#   'offense': 'Murder',
#   'punishment': 'Death'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 82/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10484 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5159793,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 83/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12488 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5157700',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'One year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 84/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18318 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5162333',
#   'offense': 'Rape',
#   'punishment': 'Confinement in the penitentiary for 18 years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 85/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13261 characters.
#  Attempt 2 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5161988',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Saved intermediate results (7792 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 86/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13445 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5157808',
#   'offense': 'Statutory rape',
#   'punishment': 'Ten years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 87/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12397 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5160745',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 88/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18321 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158711',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 89/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12738 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and dismissed',
#   'id': '5163662',
#   'offense': 'Practicing optometry without a license (constitutionality '
#              "challenge to statute defining 'practice')",
#   'punishment': 'A fine of $50.00'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 90/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12094 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Motion for rehearing overruled',
#   'id': '5164177',
#   'offense': 'Murder',
#   'punishment': 'Ten years in the penitentiary'}]
#  Saved intermediate results (7797 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 91/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11273 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5160013',
#   'offense': 'Possessing intoxicating liquor',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 92/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11482 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Motion for rehearing overruled',
#   'id': '5157140',
#   'offense': 'Transportation of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 93/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12566 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5160489',
#   'offense': 'Unlawful possession of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of four years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 94/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11598 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5163317',
#   'offense': 'Burglary',
#   'punishment': 'Two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 95/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13992 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5162214',
#   'offense': 'Possessing intoxicating liquor',
#   'punishment': 'Two years in the penitentiary'}]
#  Saved intermediate results (7802 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 96/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12528 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158066',
#   'offense': 'Burglary',
#   'punishment': 'Four years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 97/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9483 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158343',
#   'offense': 'Assault with intent to rape',
#   'punishment': 'Confinement in the penitentiary for a period of not less than '
#                 'five nor more than fifteen years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 98/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11376 characters.
#  Attempt 1 successful.
# [{'decision': 'Reformed and Affirmed',
#   'id': '5157498',
#   'offense': 'Unlawful transportation of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for not less than one nor '
#                 'more than two years (reformed sentence)'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 99/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7068 characters.
#  Attempt 1 successful.
# [{'decision': 'Dismissed',
#   'id': '5159222',
#   'offense': 'Barter and sale of a beaver pelt',
#   'punishment': 'A fine of $10.00'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 100/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11819 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5158451,
#   'offense': None,
#   'punishment': None}]
#  Saved intermediate results (7807 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 101/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8675 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5160552',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 102/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14261 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5159376',
#   'offense': 'Aggravated assault (originally indicted for assault with intent '
#              'to murder)',
#   'punishment': 'A fine of one thousand dollars and two years confinement in '
#                 'the county jail'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 103/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9353 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5157671',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 104/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9735 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5158577',
#   'offense': 'Transportation of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 105/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7330 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5163494',
#   'offense': 'Selling intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Saved intermediate results (7812 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 106/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9986 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5160710',
#   'offense': 'Robbery by assault',
#   'punishment': 'Five years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 107/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8013 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5157844,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 108/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9337 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and dismissed',
#   'id': '5164096',
#   'offense': 'Operating as a pawnbroker and receiving goods in pledge without '
#              'having complied with the statutes regulating pawnbrokers '
#              '(Insufficiency of Information)',
#   'punishment': 'Fine of $25.00'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 109/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7523 characters.
#  Attempt 1 successful.
# [{'decision': 'Denied (writ of habeas corpus)',
#   'id': '5158758',
#   'offense': 'Original application for a writ of habeas corpus following '
#              'conviction for murder',
#   'punishment': 'Death'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 110/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9118 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and bail granted',
#   'id': '5160047',
#   'offense': 'Murder (Appeal from order denying bail)',
#   'punishment': 'Bail granted in the sum of $10,000.00'}]
#  Saved intermediate results (7817 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 111/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9021 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5157970',
#   'offense': 'Habeas Corpus challenging misdemeanor conviction legality based '
#              'on Justice of the Peace fee waiver',
#   'punishment': 'None stated'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 112/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8592 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5159704',
#   'offense': 'Cattle theft',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 113/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8963 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158036',
#   'offense': 'felony theft',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 114/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11389 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5161859',
#   'offense': 'Perjury',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 115/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11360 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5161101',
#   'offense': 'Aggravated assault',
#   'punishment': 'Three months in the county jail'}]
#  Saved intermediate results (7822 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 116/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11940 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5158146',
#   'offense': 'Aggravated assault',
#   'punishment': 'A fine of twenty-five dollars and confinement in jail for '
#                 'thirty days'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 117/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8515 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5160522',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 118/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7255 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5157223',
#   'offense': 'Aggravated assault',
#   'punishment': 'A fine of $50.00 and thirty days’ imprisonment in jail'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 119/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7314 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5158507',
#   'offense': 'Bigamy',
#   'punishment': 'Confinement in the penitentiary for five years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 120/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8611 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and Relator discharged',
#   'id': '5161960',
#   'offense': 'Habeas Corpus Petition challenging conviction based on '
#              'disqualification of Justice of the Peace',
#   'punishment': 'None stated'}]
#  Saved intermediate results (7827 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 121/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8311 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and bail granted',
#   'id': '5160282',
#   'offense': 'Murder (Appeal from order denying bail)',
#   'punishment': 'Bail granted in the sum of $7,500.00'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 122/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 6777 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and bail granted',
#   'id': '5161608',
#   'offense': 'Habeas Corpus / Appeal regarding bail eligibility',
#   'punishment': 'Granted bail in the sum of $7,500.00'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 123/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 18566 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5161649',
#   'offense': 'Murder',
#   'punishment': 'Confinement in the penitentiary for 35 years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 124/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10636 characters.
#  Attempt 1 successful.
# [{'decision': 'Overruled',
#   'id': '5163261',
#   'offense': 'Unlawful manufacture of intoxicating liquor',
#   'punishment': 'Eighteen months in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 125/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11733 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5159977,
#   'offense': None,
#   'punishment': None}]
#  Saved intermediate results (7832 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 126/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11127 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Motion for rehearing overruled',
#   'id': '5163865',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Not less than one nor more than two years in the penitentiary '
#                 '(corrected sentence)'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 127/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10267 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5168969',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'One year confinement in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 128/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9712 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed. Motion for rehearing overruled',
#   'id': '5170863',
#   'offense': 'Possession of a still and mash for the purpose of manufacturing '
#              'intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 129/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8459 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5167698',
#   'offense': 'Selling intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 130/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7235 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed / Motion for rehearing overruled',
#   'id': '5170195',
#   'offense': 'Possessing intoxicating liquor for purposes of sale',
#   'punishment': 'One year in the penitentiary'}]
#  Saved intermediate results (7837 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 131/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7235 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Motion for rehearing overruled',
#   'id': '5167270',
#   'offense': 'Selling intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 132/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8923 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5165466',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 133/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 16412 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5170600',
#   'offense': 'Cattle theft',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 134/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8080 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5167342',
#   'offense': 'Robbery by assault',
#   'punishment': 'Five years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 135/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7447 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and dismissed',
#   'id': '5169641',
#   'offense': 'Burglary with intent to commit theft',
#   'punishment': 'Two years in the penitentiary'}]
#  Saved intermediate results (7842 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 136/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7386 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5171171',
#   'offense': 'Violating a city ordinance',
#   'punishment': '$150.00 fine'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 137/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8790 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5171329',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 138/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10093 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5166700',
#   'offense': 'Swindling (felony charge based on worthless check)',
#   'punishment': 'Two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 139/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11826 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5168403',
#   'offense': 'Murder',
#   'punishment': 'Five years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 140/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12932 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5170458',
#   'offense': 'Manufacturing intoxicating liquor',
# ...
#   'id': '5179603',
#   'offense': 'Unlawful possession of a still for the manufacture of '
#              'intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 197/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7126 characters.
#  Attempt 1 successful.
# [{'decision': 'Dismissed',
#   'id': '5180715',
#   'offense': 'Felony theft',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 198/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7130 characters.
#  Attempt 2 successful.
# [{'decision': 'Dismissed',
#   'id': '5180264',
#   'offense': 'Felony theft (appeal dismissed due to escape from custody)',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 199/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7825 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5177512',
#   'offense': 'Unlawful possession of intoxicating liquor for the purpose of '
#              'sale',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 200/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9428 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5177556',
#   'offense': 'Forgery',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Saved intermediate results (7907 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 201/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9879 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5178676',
#   'offense': 'Manufacturing intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 202/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14305 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5180394',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 203/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8636 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5185374',
#   'offense': 'Aggravated assault',
#   'punishment': 'A fine of $200.00, and three months in the county jail'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 204/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9781 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed; Motion for rehearing and writ of certiorari overruled',
#   'id': '5184819',
#   'offense': 'Unlawfully transporting intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 205/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 17004 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5185256',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'One year in the penitentiary'}]
#  Saved intermediate results (7912 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 206/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11930 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5185599',
#   'offense': 'The unlawful possession of intoxicating liquor for the purpose '
#              'of sale',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 207/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9800 characters.
#  Attempt 1 successful.
# [{'decision': 'Overruled',
#   'id': '5183343',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for three years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 208/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7644 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5183981',
#   'offense': 'Possessing intoxicating liquor for the purpose of sale',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 209/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10627 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5182920',
#   'offense': 'Murder',
#   'punishment': 'Fifty years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 210/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12008 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5184509',
#   'offense': 'Rape',
#   'punishment': 'Five years in the penitentiary'}]
#  Saved intermediate results (7917 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 211/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9540 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5182412',
#   'offense': 'Possession of a still for the purpose of manufacturing '
#              'intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 212/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13781 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5181324',
#   'offense': 'Transporting intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 213/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7836 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5185146',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 214/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9511 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5185207',
#   'offense': 'Unlawful transportation of intoxicating liquor',
#   'punishment': 'Two years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 215/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12628 characters.
#  Attempt 2 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5183690',
#   'offense': 'Rape (of a female under the age of eighteen years)',
#   'punishment': 'Seventeen years in the penitentiary'}]
#  Saved intermediate results (7922 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 216/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9383 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5184176',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'Three years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 217/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8063 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5183142,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 218/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 16956 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5182625',
#   'offense': 'Driving an automobile on a public highway while intoxicated',
#   'punishment': 'A fine of five dollars'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 219/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9418 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5181020',
#   'offense': 'Manufacturing intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 220/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10134 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5183291',
#   'offense': 'Unlawful transportation of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Saved intermediate results (7927 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 221/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8249 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5180548',
#   'offense': 'Possessing intoxicating liquor for purposes of sale',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 222/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7908 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5186370',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale '
#              '(appeal due to defective indictment and unresponsive verdict)',
#   'punishment': 'Confinement in the penitentiary for two years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 223/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9267 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed / Rehearing Overruled',
#   'id': '5182846',
#   'offense': 'Possessing intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 224/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9424 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed / Rehearing Overruled',
#   'id': '5186071',
#   'offense': 'Possession of a still for the manufacture of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of three years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 225/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10952 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5183468',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Saved intermediate results (7932 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 226/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11236 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5181918',
#   'offense': 'Unlawful possession of intoxicating liquor for the purpose of '
#              'sale',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 227/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 13436 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5184610',
#   'offense': 'Possessing a still for manufacturing intoxicating liquor',
#   'punishment': 'Three years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 228/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9341 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5186162',
#   'offense': 'Selling intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 229/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7115 characters.
#  Attempt 1 successful.
# [{'decision': 'Dismissed',
#   'id': '5183634',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for one year and nine months'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 230/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9429 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5184183',
#   'offense': 'Selling intoxicating liquor',
#   'punishment': 'One year imprisonment in the penitentiary'}]
#  Saved intermediate results (7937 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 231/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12820 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5185448',
#   'offense': 'Unlawfully transporting intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 232/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 8660 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5186347,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 233/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 12584 characters.
#  Attempt 1 successful.
# [{'decision': 'Reformed and affirmed (Motion for rehearing overruled)',
#   'id': '5183323',
#   'offense': 'Unlawful sale of intoxicating liquor',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 234/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 15915 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5183372',
#   'offense': 'Driving an automobile upon a public highway while intoxicated',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 235/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9207 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5186191,
#   'offense': None,
#   'punishment': None}]
#  Saved intermediate results (7942 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 236/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 14347 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5185613',
#   'offense': 'Possession of intoxicating liquor for the purpose of sale',
#   'punishment': 'Confinement in the penitentiary for one year'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 237/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 15359 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed',
#   'id': '5186393',
#   'offense': 'Possessing intoxicating liquor for purposes of sale',
#   'punishment': 'One year in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 238/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 11953 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5186251,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 239/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 16158 characters.
#  Attempt 1 successful.
# [{'decision': None,
#   'error': 'LLM skipped this case',
#   'id': 5183204,
#   'offense': None,
#   'punishment': None}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 240/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 7596 characters.
#  Attempt 2 successful.
# [{'decision': 'Affirmed',
#   'id': '5185865',
#   'offense': 'Possessing intoxicating liquor for purposes of sale',
#   'punishment': 'One year in the penitentiary'}]
#  Saved intermediate results (7947 total)
#  Cooling down API for 5 seconds...
#
# === Processing batch 241/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10366 characters.
#  Attempt 1 successful.
# [{'decision': 'Affirmed (Motion for rehearing overruled)',
#   'id': '5182769',
#   'offense': 'Unlawful manufacture of intoxicating liquor',
#   'punishment': 'Three years in the penitentiary'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 242/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 10837 characters.
#  Attempt 1 successful.
# [{'decision': 'Reversed and remanded',
#   'id': '5183900',
#   'offense': 'Unlawful manufacture of intoxicating liquor',
#   'punishment': 'Confinement in the penitentiary for a period of three years'}]
#  Cooling down API for 5 seconds...
#
# === Processing batch 243/20143 (1 cases) ===
# DEBUG: Total prompt length for this batch: 9504 characters.
#  Rate Limit (429). Pausing for 70s...

# %% [markdown]
# Cleaning of case_details_tx_with_llm.json and extraction of conviction into convictions_with_llm

# %% [markdown]
# ## Data Cleaning & Quality Control
#
# ### **Main Objective**
# To enforce the "Garbage In, Garbage Out" principle by strictly filtering the LLM outputs, ensuring that only cases with complete and valid legal metadata are admitted into the final dataset.
#
# ### **Technical Logic**
# This script acts as a quality gatekeeper between the raw AI generation and the database ingestion:
#
# * **Type Normalization:** It sanitizes the unique identifiers (`id`), converting them from potentially messy strings (with whitespace or quotes) into clean integers. This ensures the JSON data will join correctly with the CSV files created earlier.
# * **Strict Validation Logic:** It applies a boolean filter: a case is preserved **only if** both the `offense` and `decision` fields are present and non-empty. This prevents the Graph Database from being populated with "ghost nodes" that have no legal value.
# * **Graceful Degradation:** While `offense` and `decision` are mandatory, the script handles the `punishment` field more flexibly. If the LLM failed to extract a punishment (or if none was stated), it defaults the value to `"None stated"` rather than discarding the entire case, maximizing data retention without compromising integrity.

# %%
import json
import os
import pandas as pd

# Configurazione
INPUT_FILE = "case_details_tx_with_llm.json"
OUTPUT_FILE = "case_details_tx_CLEANED.json"

def clean_data():
    print(f"--- AVVIO PULIZIA DATI ---")
    
    if not os.path.exists(INPUT_FILE):
        print(f" Errore: Il file {INPUT_FILE} non esiste.")
        return

    # 1. Caricamento
    print(f"Caricamento di {INPUT_FILE}...")
    try:
        with open(INPUT_FILE, "r", encoding="utf-8") as f:
            raw_data = json.load(f)
    except json.JSONDecodeError:
        print(" Errore: Il file JSON è corrotto.")
        return

    print(f"Totale record grezzi: {len(raw_data)}")

    cleaned_data = []
    skipped_count = 0
    
    # 2. Iterazione e Pulizia
    for item in raw_data:
        # A. Normalizzazione ID
        raw_id = item.get("id")
        try:
            # Converte in stringa, rimuove spazi/virgolette, converte in int
            clean_id = int(str(raw_id).strip().replace('"', '').replace("'", ""))
        except (ValueError, TypeError):
            # Se l'ID non è valido (es. null), scarta il caso
            skipped_count += 1
            continue

        # B. Controllo Campi Obbligatori
        offense = item.get("offense")
        decision = item.get("decision")
        punishment = item.get("punishment") # Opzionale ma utile tenerlo pulito

        # Funzione helper per verificare se un campo è valido (non None, non stringa vuota)
        def is_valid(text):
            return text is not None and str(text).strip() != "" and str(text).lower() != "null"

        # Teniamo il caso SOLO SE ha un reato E una decisione
        if is_valid(offense) and is_valid(decision):
            cleaned_item = {
                "id": clean_id, # Ora è sicuramente un intero (int)
                "offense": str(offense).strip(),
                "punishment": str(punishment).strip() if is_valid(punishment) else "None stated",
                "decision": str(decision).strip()
            }
            cleaned_data.append(cleaned_item)
        else:
            skipped_count += 1

    # 3. Salvataggio
    print(f"\n--- RISULTATI ---")
    print(f" Casi validi mantenuti: {len(cleaned_data)}")
    print(f" Casi scartati (incompleti/errori): {skipped_count}")

    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(cleaned_data, f, indent=2, ensure_ascii=False)
    
    print(f"\nFile pulito salvato come: {OUTPUT_FILE}")

if __name__ == "__main__":
    clean_data()
# Out:
# --- AVVIO PULIZIA DATI ---
# Caricamento di case_details_tx_with_llm.json...
# Totale record grezzi: 7947
#
# --- RISULTATI ---
#  Casi validi mantenuti: 7791
#  Casi scartati (incompleti/errori): 156
#
# File pulito salvato come: case_details_tx_CLEANED.json

# %% [markdown]
# ## Conviction Status Classifier
#
# ### **Main Objective**
# To perform a specialized, second-pass analysis on the cleaned data to determine a critical boolean data point: **Did the case result in a final conviction?** (True/False).
#
# ### **Technical Logic**
# While the previous script extracted general text fields, this script performs **binary classification** to enable filtering by "Winning" or "Losing" precedents:
#
# * **Targeted Inference:** It inputs the `Offense`, `Punishment`, and `Decision` text generated in the previous step and asks the LLM to interpret the legal outcome. For example, it understands that *"Judgment Affirmed"* equates to **True** (Convicted), while *"Reversed and Remanded"* equates to **False** (Not Convicted).
# * **Semantic Normalization:** The script maps various linguistic variations returned by the LLM (e.g., "guilty", "yes", "1", "affirmed") into a strict Python **Boolean** (`True`/`False`). This is essential for the Neo4j database, allowing for precise queries like *"Show me cases where the defense won."*
# * **Batch Efficiency & Resume Capability:** Like the previous extractor, it processes cases in batches (20 at a time) to optimize API costs. It also checks the output file on startup to identify which IDs have already been processed, allowing the script to pick up exactly where it left off in case of interruption.
# * **Data Validation Layer:** It includes a specific fix to ensure `ID`s are treated as integers (`id_int`), preventing type mismatch errors that could occur when merging data from different sources (JSON vs CSV).

# %%
import pandas as pd
import json
import requests
from pprint import pprint
import os
import time
import re

# ---------- JSON extraction helpers ----------
def extract_json_array(text):
    match = re.search(r'\[.*\]', text, re.DOTALL)
    if match:
        try:
            return json.loads(match.group(0))
        except json.JSONDecodeError:
            return None
    return None

def extract_json_objects(text):
    matches = re.findall(r'\{.*?\}', text, re.DOTALL)
    objs = []
    for m in matches:
        try:
            objs.append(json.loads(m))
        except json.JSONDecodeError:
            continue
    return objs if objs else None

# ---------- Load API key ----------
api_key = os.getenv("GEMINI_API_KEY") or os.getenv("GOOGLE_API_KEY")

if not api_key:
    # Fallback manuale se le env vars non sono settate
    key_file = "key.txt"
    try:
        with open(key_file, "r", encoding="utf-8") as f:
            api_key = f.read().strip()
            print(f" API Key loaded successfully from {key_file}.")
    except FileNotFoundError:
        print(f" ERROR: API Key not found.")
        api_key = ""

# ---------- Gemini API Config ----------
GEMINI_MODEL = "gemini-2.5-flash" 
API_URL = f"https://generativelanguage.googleapis.com/v1beta/models/{GEMINI_MODEL}:generateContent?key={api_key}"
HEADERS = {'Content-Type': 'application/json'}

# ---------- Parameters ----------
json_input_file = "case_details_tx_CLEANED.json" 
prompt_template_path = "prompt_conviction.txt" 
output_file = "convictions_with_llm.json"

# Configurazione Batch
batch_size = 5
save_every_n_batches = 5

# ---------- Load Resources ----------
if not os.path.exists(prompt_template_path):
    print(f" ERROR: {prompt_template_path} not found. Create it first.")
    exit()
with open(prompt_template_path, "r", encoding="utf-8") as f:
    prompt_template = f.read()

print(f" Loading extracted details from {json_input_file}...")
if not os.path.exists(json_input_file):
    print(f" ERROR: Input file {json_input_file} not found.")
    exit()

try:
    with open(json_input_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    df = pd.DataFrame(data) 
    print(f" Loaded {len(df)} raw records from JSON.")
except Exception as e:
    print(f" Error reading JSON: {e}")
    exit()

# --- ### FIX: PREPARAZIONE DATAFRAME ### ---
# 1. Assicuriamoci che l'ID sia un intero per fare confronti corretti
# (Usa 'coerce' per trasformare errori in NaN, poi riempi con 0 e converti a int)
df['id_int'] = pd.to_numeric(df['id'], errors='coerce').fillna(0).astype(int)

# 2. Creiamo df_valid rimuovendo ID nulli o zero (sicurezza)
df_valid = df[df['id_int'] > 0].copy()
print(f" Validated dataframe size: {len(df_valid)} records.")
# -------------------------------------------

# Caricamento risultati esistenti (Resume capability)
if os.path.exists(output_file):
    try:
        with open(output_file, "r", encoding="utf-8") as f:
            results = json.load(f)
        print(f" Loaded {len(results)} existing results from {output_file}")
    except json.JSONDecodeError:
        results = []
else:
    results = []

# Crea un set di ID già fatti
done_ids = set()
for r in results:
    if r.get("id") is not None:
        try:
            done_ids.add(int(r["id"]))
        except:
            pass

# Filtra le righe da processare usando df_valid
rows_to_process = [row for _, row in df_valid.iterrows() if row["id_int"] not in done_ids]
total_batches = (len(rows_to_process) + batch_size - 1) // batch_size

print(f" Found {len(rows_to_process)} NEW valid cases to process.")

def build_cases_block(rows):
    lines = []
    for row in rows:
        # Gestione sicura dei campi (se sono None mette stringa vuota)
        offense = row.get("offense") or "Unknown"
        punishment = row.get("punishment") or "Unknown"
        decision = row.get("decision") or "Unknown"
        
        lines.append(
            f'Case:\n'
            f'Id: {row["id_int"]}\n'
            f'Offense: "{offense}"\n'
            f'Punishment: "{punishment}"\n'
            f'Decision: "{decision}"\n'
        )
    return "\n".join(lines)

# ==========================================
#       MAIN LOOP
# ==========================================

if total_batches == 0:
    print("Nothing to do! All cases processed.")
    exit()

for batch_idx in range(total_batches):
    batch_rows = rows_to_process[batch_idx*batch_size : (batch_idx+1)*batch_size]
    print(f"\n=== Processing batch {batch_idx+1}/{total_batches} ({len(batch_rows)} cases) ===")

    cases_block = build_cases_block(batch_rows)
    prompt_filled = prompt_template.replace("{cases_block}", cases_block)

    system_instruction = "You are a precise legal assistant. Follow the instructions exactly and output ONLY valid JSON."
    
    payload = {
        "contents": [{"parts": [{"text": prompt_filled}]}],
        "systemInstruction": {"parts": [{"text": system_instruction}]},
        # --- SAFETY BLOCK REMOVED  ---
        "safetySettings": [
            {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
            {"category": "HARM_CATEGORY_CIVIC_INTEGRITY", "threshold": "BLOCK_NONE"}
        ],
        # ------------------------------
        "generationConfig": {
            "maxOutputTokens": 2048, 
            "responseMimeType": "application/json"
        }
    }

    # --- Retry Loop ---
    max_retries = 5
    output_text = None
    
    for attempt in range(1, max_retries + 1):
        try:
            response = requests.post(API_URL, headers=HEADERS, json=payload)
            
            if response.status_code == 429:
                wait = 20 + (5 * attempt)
                print(f"Rate Limit (429). Pausing {wait}s...", end="\r")
                time.sleep(wait)
                continue

            response.raise_for_status()
            result = response.json()
            candidate = result.get('candidates', [{}])[0]
            parts = candidate.get('content', {}).get('parts', [{}])
            output_text = parts[0].get('text', '').strip()
            print(f" Attempt {attempt} successful.")
            break

        except Exception as e:
            print(f" Attempt {attempt} failed: {e}")
            time.sleep(2)

    # --- Parsing ---
    if not output_text:
        print(" Skipping batch (No output).")
        continue
    else:
        parsed = None
        try:
            parsed = json.loads(output_text)
            if isinstance(parsed, dict): parsed = [parsed]
        except json.JSONDecodeError:
            parsed = extract_json_array(output_text) or extract_json_objects(output_text)

        if not parsed:
            print(" Invalid JSON response.")
            continue
            
        # --- Normalizzazione Risultati Batch ---
        normalized = []
        
        # Mappa ID -> Riga originale per recuperare i dati se l'LLM sbaglia
        batch_map = {r["id_int"]: r for r in batch_rows}
        
        for obj in parsed:
            # Recupera ID
            try:
                obj_id = int(obj.get("id"))
            except (ValueError, TypeError):
                continue 
            
            if obj_id in batch_map:
                convicted_val = obj.get("convicted")
                
                # Normalizza Booleano
                if isinstance(convicted_val, str):
                    low = convicted_val.strip().lower()
                    if low in ["true", "yes", "1", "affirmed", "guilty"]: convicted_val = True
                    elif low in ["false", "no", "0", "reversed", "acquitted"]: convicted_val = False
                    else: convicted_val = None
                elif not isinstance(convicted_val, bool):
                    convicted_val = None
                
                normalized.append({"id": obj_id, "convicted": convicted_val})
                # Rimuoviamo dalla mappa per sapere chi manca
                if obj_id in batch_map:
                    del batch_map[obj_id] 

        # Aggiungiamo i casi che l'LLM ha dimenticato nel batch come None
        for missing_id in batch_map:
             normalized.append({"id": missing_id, "convicted": None})

        if len(normalized) > 0:
            pprint(normalized[:1]) # Mostra solo il primo per pulizia console
        results.extend(normalized)

    # --- Save ---
    if (batch_idx + 1) % save_every_n_batches == 0 or batch_idx == total_batches - 1:
        with open(output_file, "w", encoding="utf-8") as f:
            json.dump(results, f, indent=2, ensure_ascii=False)
        print(f" Saved intermediate results ({len(results)} total)")

    # Pausa standard per evitare 429 aggressivi
    time.sleep(4)

print(f"\n Process complete. Conviction outputs saved to {output_file}")
# Out:
#  API Key loaded successfully from key.txt.
#  Loading extracted details from case_details_tx_CLEANED.json...
#  Loaded 7791 raw records from JSON.
#  Validated dataframe size: 7791 records.
#  Loaded 7093 existing results from convictions_with_llm.json
#  Found 698 NEW valid cases to process.
#
# === Processing batch 1/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 2/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5277648}]
#
# === Processing batch 3/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5277350}]
#
# === Processing batch 4/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 5/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5797503}]
#  Saved intermediate results (7108 total)
#
# === Processing batch 6/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 7/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 8/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 9/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5797825}]
#
# === Processing batch 10/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5805237}]
#  Saved intermediate results (7118 total)
#
# === Processing batch 11/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5110417}]
#
# === Processing batch 12/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5120601}]
#
# === Processing batch 13/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5126354}]
#
# === Processing batch 14/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5124527}]
#
# === Processing batch 15/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5128787}]
#  Saved intermediate results (7143 total)
#
# === Processing batch 16/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5137938}]
#
# === Processing batch 17/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5138104}]
#
# === Processing batch 18/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5137305}]
#
# === Processing batch 19/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5135128}]
#
# === Processing batch 20/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 21/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5134992}]
#
# === Processing batch 22/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5138427}]
#
# === Processing batch 23/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5141279}]
#
# === Processing batch 24/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5139090}]
#
# === Processing batch 25/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5139773}]
#  Saved intermediate results (7188 total)
#
# === Processing batch 26/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5147191}]
#
# === Processing batch 27/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5142534}]
#
# === Processing batch 28/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5147616}]
#
# === Processing batch 29/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5143321}]
#
# === Processing batch 30/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5152008}]
#  Saved intermediate results (7213 total)
#
# === Processing batch 31/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5149711}]
#
# === Processing batch 32/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5151377}]
#
# === Processing batch 33/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5152709}]
#
# === Processing batch 34/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5149438}]
#
# === Processing batch 35/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5152281}]
#  Saved intermediate results (7238 total)
#
# === Processing batch 36/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5150039}]
#
# === Processing batch 37/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5149897}]
#
# === Processing batch 38/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5152803}]
#
# === Processing batch 39/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5150451}]
#
# === Processing batch 40/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5148983}]
#  Saved intermediate results (7263 total)
#
# === Processing batch 41/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5151060}]
#
# === Processing batch 42/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153359}]
#
# === Processing batch 43/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5151642}]
#
# === Processing batch 44/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5150816}]
#
# === Processing batch 45/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5150913}]
#  Saved intermediate results (7288 total)
#
# === Processing batch 46/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5149127}]
#
# === Processing batch 47/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5153765}]
#
# === Processing batch 48/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5149466}]
#
# === Processing batch 49/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5150223}]
#
# === Processing batch 50/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5154788}]
#  Saved intermediate results (7313 total)
#
# === Processing batch 51/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5149850}]
#
# === Processing batch 52/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5152394}]
#
# === Processing batch 53/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5149537}]
#
# === Processing batch 54/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5142329}]
#
# === Processing batch 55/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5142585}]
#  Saved intermediate results (7338 total)
#
# === Processing batch 56/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5152679}]
#
# === Processing batch 57/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5150147}]
#
# === Processing batch 58/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5152971}]
#
# === Processing batch 59/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5152414}]
#
# === Processing batch 60/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5150202}]
#  Saved intermediate results (7363 total)
#
# === Processing batch 61/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5154814}]
#
# === Processing batch 62/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5153733}]
#
# === Processing batch 63/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5154345}]
#
# === Processing batch 64/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5152140}]
#
# === Processing batch 65/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5153935}]
#  Saved intermediate results (7388 total)
#
# === Processing batch 66/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5154203}]
#
# === Processing batch 67/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5154754}]
#
# === Processing batch 68/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5154042}]
#
# === Processing batch 69/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5154077}]
#
# === Processing batch 70/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153502}]
#  Saved intermediate results (7413 total)
#
# === Processing batch 71/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153048}]
#
# === Processing batch 72/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5157646}]
#
# === Processing batch 73/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153320}]
#
# === Processing batch 74/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5155455}]
#
# === Processing batch 75/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5155558}]
#  Saved intermediate results (7438 total)
#
# === Processing batch 76/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5155067}]
#
# === Processing batch 77/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153210}]
#
# === Processing batch 78/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5153683}]
#
# === Processing batch 79/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153188}]
#
# === Processing batch 80/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5156796}]
#  Saved intermediate results (7463 total)
#
# === Processing batch 81/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5155849}]
#
# === Processing batch 82/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5158806}]
#
# === Processing batch 83/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5153708}]
#
# === Processing batch 84/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5156325}]
#
# === Processing batch 85/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5155362}]
#  Saved intermediate results (7488 total)
#
# === Processing batch 86/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5156774}]
#
# === Processing batch 87/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5155045}]
#
# === Processing batch 88/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5157263}]
#
# === Processing batch 89/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5153361}]
#
# === Processing batch 90/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5154533}]
#  Saved intermediate results (7513 total)
#
# === Processing batch 91/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5156835}]
#
# === Processing batch 92/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5155204}]
#
# === Processing batch 93/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5157197}]
#
# === Processing batch 94/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 95/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5155905}]
#  Saved intermediate results (7533 total)
#
# === Processing batch 96/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 97/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5154481}]
#
# === Processing batch 98/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5154669}]
#
# === Processing batch 99/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5156680}]
#
# === Processing batch 100/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5157315}]
#  Saved intermediate results (7553 total)
#
# === Processing batch 101/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5156650}]
#
# === Processing batch 102/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5158720}]
#
# === Processing batch 103/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5156085}]
#
# === Processing batch 104/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5156982}]
#
# === Processing batch 105/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5158289}]
#  Saved intermediate results (7578 total)
#
# === Processing batch 106/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5157851}]
#
# === Processing batch 107/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5158177}]
#
# === Processing batch 108/140 (5 cases) ===
#  Attempt 1 successful.
#  Skipping batch (No output).
#
# === Processing batch 109/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5158219}]
#
# === Processing batch 110/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5157941}]
#  Saved intermediate results (7598 total)
#
# === Processing batch 111/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5157700}]
#
# === Processing batch 112/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5158711}]
#
# === Processing batch 113/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5160489}]
#
# === Processing batch 114/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5157498}]
#
# === Processing batch 115/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5158577}]
#  Saved intermediate results (7623 total)
#
# === Processing batch 116/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5160047}]
#
# === Processing batch 117/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5161101}]
#
# === Processing batch 118/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5161960}]
#
# === Processing batch 119/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5163865}]
#
# === Processing batch 120/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5167270}]
#  Saved intermediate results (7648 total)
#
# === Processing batch 121/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5171171}]
#
# === Processing batch 122/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5170521}]
#
# === Processing batch 123/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5165076}]
#
# === Processing batch 124/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5784458}]
#
# === Processing batch 125/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5786324}]
#  Saved intermediate results (7673 total)
#
# === Processing batch 126/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5783088}]
#
# === Processing batch 127/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5783958}]
#
# === Processing batch 128/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5174386}]
#
# === Processing batch 129/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5174655}]
#
# === Processing batch 130/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5181319}]
#  Saved intermediate results (7698 total)
#
# === Processing batch 131/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5180050}]
#
# === Processing batch 132/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5177328}]
#
# === Processing batch 133/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5180264}]
#
# === Processing batch 134/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5185374}]
#
# === Processing batch 135/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5183981}]
#  Saved intermediate results (7723 total)
#
# === Processing batch 136/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5185146}]
#
# === Processing batch 137/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5181020}]
#
# === Processing batch 138/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': True, 'id': 5186071}]
#
# === Processing batch 139/140 (5 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5183634}]
#
# === Processing batch 140/140 (3 cases) ===
#  Attempt 1 successful.
# [{'convicted': False, 'id': 5185613}]
#  Saved intermediate results (7746 total)
#
#  Process complete. Conviction outputs saved to convictions_with_llm.json
